# %% [markdown]
# ### Ivy Wong, SeatGeek API Package (seatgeekpkg)

# %% [markdown]
# #### This python package is an API wrapper around the SeatGeek API and returns functions that gives information about upcoming concerts, cheap tickets, recommendations. This package was made with the intention of retrieving upcoming live events data and process them in an easily readable format. It also aims to provide access into the SeatGeek API with ease and allows a user to play aroud with the API for their apps.
#
# #### The SeatGeek Platform provides detailed information of live events in America, including the venues, ticket prices, performers, etc. SeatGeek Platform has a number of parameters that will be used for the purposes of this project, such as: Events, Performers, Venues, and Recommendations. The parameters Events, Performers and Venues will be used to collect metadata of all live events data so far into a readable dataframe for readability. Recommendations and Recommended Performers will be used to create a function which will output a list of recommended shows/ performers based on the function input.

# %% [markdown]
# ### Link to TestPyPi package and repo

# %% [markdown]
# TestPypi: https://test.pypi.org/project/seatgeekpkg/0.1.4/
#
# Repo: https://github.com/QMSS-G5072-2022/seatgeekpkg_wong_ivy

# %% [markdown]
# ### Directly installing from TestPyPi

# %%
pip install -i https://test.pypi.org/simple/ seatgeekpkg==0.1.4
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Requirement already satisfied: seatgeekpkg==0.1.4 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: pytest<8.0.0,>=7.2.0 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from seatgeekpkg==0.1.4) (7.2.0)
# Requirement already satisfied: python-dotenv<0.22.0,>=0.21.0 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from seatgeekpkg==0.1.4) (0.21.0)
# Requirement already satisfied: pandas<2.0.0,>=1.5.2 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from seatgeekpkg==0.1.4) (1.5.2)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from seatgeekpkg==0.1.4) (2.28.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.5.2->seatgeekpkg==0.1.4) (2021.3)
# Requirement already satisfied: numpy>=1.20.3 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.5.2->seatgeekpkg==0.1.4) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.5.2->seatgeekpkg==0.1.4) (2.8.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pytest<8.0.0,>=7.2.0->seatgeekpkg==0.1.4) (1.0.0)
# Requirement already satisfied: iniconfig in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pytest<8.0.0,>=7.2.0->seatgeekpkg==0.1.4) (1.1.1)
# Requirement already satisfied: packaging in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pytest<8.0.0,>=7.2.0->seatgeekpkg==0.1.4) (21.3)
# Requirement already satisfied: tomli>=1.0.0 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pytest<8.0.0,>=7.2.0->seatgeekpkg==0.1.4) (1.2.2)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pytest<8.0.0,>=7.2.0->seatgeekpkg==0.1.4) (1.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from pytest<8.0.0,>=7.2.0->seatgeekpkg==0.1.4) (21.4.0)
# Requirement already satisfied: six>=1.5 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.5.2->seatgeekpkg==0.1.4) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->seatgeekpkg==0.1.4) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->seatgeekpkg==0.1.4) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->seatgeekpkg==0.1.4) (1.26.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.28.1->seatgeekpkg==0.1.4) (2.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/ivster/opt/anaconda3/lib/python3.9/site-packages (from packaging->pytest<8.0.0,>=7.2.0->seatgeekpkg==0.1.4) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import the package

# %%
from seatgeekpkg import seatgeekpkg

# %% [markdown]
# ### Running the functions from the package

# %% [markdown]
# #### This function returns a dataframe of the most popular upcoming concerts in Los Angeles.

# %%
seatgeekpkg.popular_events(client_key, 'Los Angeles')
# Out:
# Status Code: 200
#                       Artists  Scores
# 0               Laura Elliott    0.28
# 1                   Leikeli47    0.32
# 2              Reyna Tropical    0.26
# 3                Roc Marciano    0.28
# 4          Harry Connick, Jr.    0.38
# 5            The Linda Lindas    0.41
# 6             Hot Chip DJ-set    0.32
# 7   The Allman Family Revival    0.36
# 8                Devon Allman    0.32
# 9                Ivan Neville    0.36
# 10                Maggie Rose    0.30
# 11                Duane Betts    0.33
# 12                 Jimmy Hall    0.36
# 13          Los Straitjackets    0.30
# 14         Harry Connick, Jr.    0.38

# %% [markdown]
# #### This function returns a dataframe of recommended events and artists related to Adele.

# %%
seatgeekpkg.recommend_me(client_key, 'adele', '90001')
# Out:
# Status Code: 200
# Status Code: 200
#                                 Names            Type  \
# 0                 Cali Vibes Festival  music_festival
# 1                       Damian Marley            band
# 2                           Ballyhoo!            band
# 3                        The Movement            band
# 4                     Fortunate Youth            band
# 5                            Katastro            band
# 6                           Alborosie            band
# 7                 Method Man & Redman            band
# 8                        Common Kings            band
# 9                         Denm - Band            band
# 10                        Dirty Heads            band
# 11               Squirrel Nut Zippers            band
# 12  Stagecoach Country Music Festival  music_festival
# 13                           Keb' Mo'            band
# 14                       Marty Stuart            band
# 15              Mary Chapin Carpenter            band
# 16                        Bryan Adams            band
# 17                              Nelly            band
# 18                         Nikki Lane            band
# 19                         Stagecoach            band
# 20                       Old Dominion            band
# 21                        Jaime Wyatt            band
# 22                         Corey Kent            band
# 23                         Kane Brown            band
# 24                      Gabby Barrett            band
# 25                        Morgan Wade            band
# 26                          Lily Rose            band
# 27                       Logan Ledger            band
# 28                           Tre Burt            band
# 29                    Kameron Marlowe            band
# 30                          Niko Moon            band
# 31                      Restless Road            band
# 32                        Cooper Alan            band
# 33                         Abbey Cone            band
# 34                         Avery Anna            band
# 35                     Tommy Emmanuel            band
# 36                       Eric Johnson            band
# 37                        Mindi Abair            band
# 38                        Robert Cray            band
# 39                        Hollie Cook            band
# 40                           Dub Club            band
# 41                         Leo Kottke            band
# 42                        Ace Frehley            band
# 43                       Eric Steckel            band
# 44             Glenn Miller Orchestra            band
# 45                             Kimbra            band
#
#                                                 Links
# 0    https://seatgeek.com/cali-vibes-festival-tickets
# 1          https://seatgeek.com/damian-marley-tickets
# 2               https://seatgeek.com/ballyhoo-tickets
# 3           https://seatgeek.com/the-movement-tickets
# 4        https://seatgeek.com/fortunate-youth-tickets
# 5               https://seatgeek.com/katastro-tickets
# 6              https://seatgeek.com/alborosie-tickets
# 7      https://seatgeek.com/method-man-redman-tickets
# 8           https://seatgeek.com/common-kings-tickets
# 9              https://seatgeek.com/denm-band-tickets
# 10           https://seatgeek.com/dirty-heads-tickets
# 11  https://seatgeek.com/squirrel-nut-zippers-tickets
# 12  https://seatgeek.com/stagecoach-country-music-...
# 13                https://seatgeek.com/keb-mo-tickets
# 14          https://seatgeek.com/marty-stuart-tickets
# 15  https://seatgeek.com/mary-chapin-carpenter-tic...
# 16           https://seatgeek.com/bryan-adams-tickets
# 17                 https://seatgeek.com/nelly-tickets
# 18            https://seatgeek.com/nikki-lane-tickets
# 19            https://seatgeek.com/stagecoach-tickets
# 20          https://seatgeek.com/old-dominion-tickets
# 21           https://seatgeek.com/jaime-wyatt-tickets
# 22            https://seatgeek.com/corey-kent-tickets
# 23            https://seatgeek.com/kane-brown-tickets
# 24         https://seatgeek.com/gabby-barrett-tickets
# 25           https://seatgeek.com/morgan-wade-tickets
# 26             https://seatgeek.com/lily-rose-tickets
# 27          https://seatgeek.com/logan-ledger-tickets
# 28              https://seatgeek.com/tre-burt-tickets
# 29       https://seatgeek.com/kameron-marlowe-tickets
# 30             https://seatgeek.com/niko-moon-tickets
# 31         https://seatgeek.com/restless-road-tickets
# 32           https://seatgeek.com/cooper-alan-tickets
# 33            https://seatgeek.com/abbey-cone-tickets
# 34            https://seatgeek.com/avery-anna-tickets
# 35        https://seatgeek.com/tommy-emmanuel-tickets
# 36          https://seatgeek.com/eric-johnson-tickets
# 37           https://seatgeek.com/mindi-abair-tickets
# 38           https://seatgeek.com/robert-cray-tickets
# 39           https://seatgeek.com/hollie-cook-tickets
# 40              https://seatgeek.com/dub-club-tickets
# 41            https://seatgeek.com/leo-kottke-tickets
# 42           https://seatgeek.com/ace-frehley-tickets
# 43          https://seatgeek.com/eric-steckel-tickets
# 44  https://seatgeek.com/glenn-miller-orchestra-ti...
# 45                https://seatgeek.com/kimbra-tickets

# %% [markdown]
# #### This function returns a list of the cheapest Sabrina Carpenter tickets, the highest price being $500.

# %%
seatgeekpkg.cheap_tix(client_key, 500, 'sabrina-carpenter')
# Out:
# Status Code: 200
#          Artist Name                 Date  Lowest Price  \
# 0  Sabrina Carpenter  2023-03-29T01:00:00            75
# 1  Sabrina Carpenter  2023-05-03T00:00:00           475
# 2  Sabrina Carpenter  2023-05-07T01:00:00            74
#
#                   Location              Title  \
# 0            Tulsa Theater  Sabrina Carpenter
# 1         Ryman Auditorium  Sabrina Carpenter
# 2  Royal Oak Music Theatre  Sabrina Carpenter
#
#                                                 Link
# 0  https://seatgeek.com/sabrina-carpenter-tickets...
# 1  https://seatgeek.com/sabrina-carpenter-tickets...
# 2  https://seatgeek.com/sabrina-carpenter-tickets...

# %%
seatgeekpkg.performer_id(client_key, 'adele')
# Out:
# 141

# %% [markdown]
# This function returns the performer ID of Adele in SeatGeek's API.

# %%
seatgeekpkg.city_status(client_key, 'New York City')
# Out:
# 200

# %% [markdown]
# This function returns the status code of a searched city.

# %% [markdown]
# ### Help functions

# %%
help(seatgeekpkg)
# Out:
# Help on module seatgeekpkg.seatgeekpkg in seatgeekpkg:
#
# NAME
#     seatgeekpkg.seatgeekpkg
#
# FUNCTIONS
#     cheap_tix(client_key, price, artist)
#         This function returns a dataframe of the cheapest tickets of an upcoming event of a specific artist.
#
#         Parameters
#         -----------
#
#         client_key : client_id authentication
#
#         price : the highest price a user is willing to pay for the event
#
#         artist : any artist that has concerts listed on SeatGeek already. should be written out in lower case, and
#                     if the artist's name has more than one word, separate each word with a dash
#
#
#         Output
#         ----------
#         The function will output a dataframe of the artist's lowest priced ticket, the location of the event,
#         the title of the event, and a link to the event.
#
#
#         Example
#         ---------
#         >>> cheap_tix(client_id, 500, 'sabrina-carpenter')
#
#             Artist           | Lowest Price | Location         | Title             | Link
#         0  Sabrina Carpenter | 90           | Tulsa Theater    | Sabrina Carpenter | https://seatgeek.com/sabrina-carpenter-tickets...
#         1  Sabrina Carpenter | 475          | Ryman Auditorium | Sabrina Carpenter | https://seatgeek.com/sabrina-carpenter-tickets...
#
#     city_status(client_key, city)
#         This function returns the status code for city-specific concerts.
#
#         Parameters
#         -------------
#         client_key : client_id authentication key
#
#         city : city name
#
#
#         Output
#         ---------
#         This function will output the status code of the GET request.
#
#
#         Example
#         ---------
#         >>> city_status(client_key, 'Los Angeles')
#         200
#
#     performer_id(client_key, artist)
#         This function returns the performer_id of a particular performer on SeatGeek's
#         API.
#
#
#         Parameters
#         ------------
#         client_key : client_id authentication key
#
#         artist : any artist name
#
#
#         Output
#         --------
#         The function will output the id number of the artist.
#
#
#         Example
#         ----------
#         >>> performer_id(client_key, 'adele')
#
#         141
#
#     popular_events(client_key, city)
#         "
#
#         A function that returns upcoming concerts in a given city, ranked by popularity.
#
#         Parameters
#         -------------
#         client_key: the API key needed to authenticate the user and gain access to SeatGeek's API
#
#         city: any city the user is interested in searching
#
#
#         Output
#         ----------
#         >>> popular_events(client_id, 'Los Angeles')
#
#
#             Artists   | Scores
#         0  Lizzo      | 0.47
#         1  Al Franken | 0.32
#
#     recommend_me(client_key, artist, postal)
#         "
#         This function uses the events endpoint and recommendations endpoint to recommend the user upcoming events
#         related to a performer and location of their choosing.
#
#         This function will have two GET requests: the first is to retrieve the performer id of the artist of the
#         user's choosing, and the second will generate a recommendations dataframe related to that artist.
#
#
#         Parameters
#         ------------
#         client_key : client_id authentication key
#
#         artist : an artist of the user's choosing. must already have concerts listed on SeatGeek
#
#         postal : the postal code of any city
#
#
#         Output
#         -----------
#         The function will generate two outputs:
#         1) the status code of each GET request, and
#         2) a dataframe of recommendations
#
#
#         Example
#         ---------
#         >>> recommend_me(client_key, 'adele', '90001')
#
#         Status Code: 200
#
#                Names           | Type            | Links
#         0  Cali Vibes Festival | music festival  | https://seatgeek.com/cali-vibes-festival-tickets
#         1  Damian Marley       | band            | https://seatgeek.com/damian-marley-tickets
#
# DATA
#     client_key = 'MzA5NzQ4NTB8MTY3MDk2MjYyMi45NDYzNjM'
#
# FILE
#     /Users/ivster/opt/anaconda3/lib/python3.9/site-packages/seatgeekpkg/seatgeekpkg.py

# %%
help(seatgeekpkg.recommend_me)
# Out:
# Help on function recommend_me in module seatgeekpkg.seatgeekpkg:
#
# recommend_me(client_key, artist, postal)
#     "
#     This function uses the events endpoint and recommendations endpoint to recommend the user upcoming events
#     related to a performer and location of their choosing.
#
#     This function will have two GET requests: the first is to retrieve the performer id of the artist of the
#     user's choosing, and the second will generate a recommendations dataframe related to that artist.
#
#
#     Parameters
#     ------------
#     client_key : client_id authentication key
#
#     artist : an artist of the user's choosing. must already have concerts listed on SeatGeek
#
#     postal : the postal code of any city
#
#
#     Output
#     -----------
#     The function will generate two outputs:
#     1) the status code of each GET request, and
#     2) a dataframe of recommendations
#
#
#     Example
#     ---------
#     >>> recommend_me(client_key, 'adele', '90001')
#
#     Status Code: 200
#
#            Names           | Type            | Links
#     0  Cali Vibes Festival | music festival  | https://seatgeek.com/cali-vibes-festival-tickets
#     1  Damian Marley       | band            | https://seatgeek.com/damian-marley-tickets

# %% [markdown]
# ### Pytests

# %% [markdown]
# ![Screenshot%202022-12-15%20at%208.55.54%20PM.png](attachment:Screenshot%202022-12-15%20at%208.55.54%20PM.png)
